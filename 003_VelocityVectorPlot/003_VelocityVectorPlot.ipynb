# %% [markdown]
# # **1. Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.tri as mtri
import numpy as np

# %% [markdown]
# ## Image Resolution

# %%
plt.rcParams['figure.dpi'] = 100

# %% [markdown]
# # **2. Input Data**

# %%
center_x = pd.read_csv('/content/drive/MyDrive/Youtube Tutorial/Matplotlib Tutorial/#1 plot unstructured grid/003_VelocityVectorPlot/center_x.csv', header=None)
center_y = pd.read_csv('/content/drive/MyDrive/Youtube Tutorial/Matplotlib Tutorial/#1 plot unstructured grid/003_VelocityVectorPlot/center_y.csv', header=None)

# %%
u = pd.read_csv('/content/drive/MyDrive/Youtube Tutorial/Matplotlib Tutorial/#1 plot unstructured grid/003_VelocityVectorPlot/velocity_u.csv',header=None)
v = pd.read_csv('/content/drive/MyDrive/Youtube Tutorial/Matplotlib Tutorial/#1 plot unstructured grid/003_VelocityVectorPlot/velocity_v.csv', header=None)

# %%
center_x
# Out:
#                    0
# 0      225879.271333
# 1      225701.318667
# 2      226382.362333
# 3      226341.185667
# 4      227037.621333
# ...              ...
# 16961  212243.489667
# 16962  212230.660667
# 16963  212096.252333
# 16964  220972.823667
# 16965  220928.304000
#
# [16966 rows x 1 columns]

# %%
center_y
# Out:
#                   0
# 0      9.028720e+06
# 1      9.028170e+06
# 2      9.027335e+06
# 3      9.026436e+06
# 4      9.025756e+06
# ...             ...
# 16961  9.094369e+06
# 16962  9.094484e+06
# 16963  9.094275e+06
# 16964  9.096399e+06
# 16965  9.096334e+06
#
# [16966 rows x 1 columns]

# %%
u
# Out:
#               0
# 0      0.012443
# 1      0.001705
# 2      0.009154
# 3      0.002360
# 4      0.009812
# ...         ...
# 16961  0.055978
# 16962  0.078733
# 16963  0.075635
# 16964  0.002392
# 16965  0.037279
#
# [16966 rows x 1 columns]

# %%
v
# Out:
#               0
# 0     -0.003259
# 1      0.000454
# 2      0.005769
# 3      0.000628
# 4      0.003764
# ...         ...
# 16961  0.136910
# 16962  0.131275
# 16963  0.105887
# 16964  0.013136
# 16965  0.002858
#
# [16966 rows x 1 columns]

# %% [markdown]
# # **3. Plot the Velocity Vector (default)**

# %%
fig, ax = plt.subplots(figsize=(8,12))

ax.quiver(center_x, center_y, u, v)

plt.show()

# %% [markdown]
# # **4. Unstructured Triangular Grid**

# %%
grid_point = pd.read_csv('/content/drive/MyDrive/Youtube Tutorial/Matplotlib Tutorial/#1 plot unstructured grid/003_VelocityVectorPlot/grid_point.csv',header=None)
grid_triangle = pd.read_csv('/content/drive/MyDrive/Youtube Tutorial/Matplotlib Tutorial/#1 plot unstructured grid/003_VelocityVectorPlot/grid_triangle.csv', header=None)

# %%
grid_triangle = grid_triangle - 1

# %%
triang = mtri.Triangulation(grid_point[0], grid_point[1], triangles=grid_triangle)

# %%
fig, ax = plt.subplots(figsize=(8,12))

ax.triplot(triang, color='black', linewidth=0.5)
ax.quiver(center_x, center_y, u, v)

plt.show()

# %% [markdown]
# # **5. Plot Grid and Velocity Vector**

# %%
fig, ax = plt.subplots(figsize=(8,8))

ax.triplot(triang, color='black', linewidth=0.5, markersize=5, markerfacecolor='black', markeredgecolor='black')
ax.quiver(center_x, center_y, u, v)

ax.set_xlim(224000,229000)
ax.set_ylim(9025000,9030000)

ax.set_ylabel('y axis', fontweight='bold', fontsize=12)
ax.set_xlabel('x axis', fontweight='bold', fontsize=12)

plt.show()

# %% [markdown]
# # **6. Customized the Arrow**

# %% [markdown]
# ## Arrow Length: scale

# %%
fig, ax = plt.subplots(figsize=(8,8))

ax.triplot(triang, color='black', linewidth=0.5, markersize=5, markerfacecolor='black', markeredgecolor='black')
ax.quiver(center_x, center_y, u, v, scale=0.1)

ax.set_xlim(224000,229000)
ax.set_ylim(9025000,9030000)

ax.set_ylabel('y axis', fontweight='bold', fontsize=12)
ax.set_xlabel('x axis', fontweight='bold', fontsize=12)

plt.show()

# %% [markdown]
# ## Arrow shape: width, headwidth, headlength, headaxislength

# %%
fig, ax = plt.subplots(figsize=(8,8))

ax.triplot(triang, color='black', linewidth=0.5, markersize=5, markerfacecolor='black', markeredgecolor='black')

ax.quiver(center_x, center_y, u, v, 
          scale=0.1, 
          width=0.005, 
          headwidth=7.5, 
          headlength=10, 
          headaxislength=5)

ax.set_xlim(224000,229000)
ax.set_ylim(9025000,9030000)

ax.set_ylabel('y axis', fontweight='bold', fontsize=12)
ax.set_xlabel('x axis', fontweight='bold', fontsize=12)

plt.show()

# %% [markdown]
# ## x and y ticks label

# %%
fig, ax = plt.subplots(figsize=(8,8))

ax.triplot(triang, color='black', linewidth=0.5, markersize=5, markerfacecolor='black', markeredgecolor='black')

ax.quiver(center_x, center_y, u, v, 
          scale=0.1, 
          width=0.005, 
          headwidth=7.5, 
          headlength=10, 
          headaxislength=5)

ax.set_xlim(224000,229000)
ax.set_ylim(9025000,9030000)

ax.set_ylabel('y axis', fontweight='bold', fontsize=12)
ax.set_xlabel('x axis', fontweight='bold', fontsize=12)

ax.set_yticks(ticks=[9025500, 9027500, 9029500])
ax.set_xticks(ticks=[224500, 226500, 228500])

ax.set_yticklabels(ax.get_yticks(), rotation=90, fontsize=12, va='center')
ax.set_xticklabels(ax.get_xticks(), fontsize=12, ha='center')

plt.show()

# %% [markdown]
# # **7. Adding an Arrow Legend**

# %%
# data for legend
legend_x = 224500
legend_y = 9029500

legend_u = 0.01 # in m/s
legend_v = 0

# plot
fig, ax = plt.subplots(figsize=(8,8))

ax.triplot(triang, color='black', linewidth=0.5, markersize=5, markerfacecolor='black', markeredgecolor='black')

ax.quiver(center_x, center_y, u, v, 
          scale=0.1, 
          width=0.005, 
          headwidth=7.5, 
          headlength=10, 
          headaxislength=5)

ax.quiver(legend_x, legend_y, legend_u, legend_v,
          scale=0.1, 
          width=0.005, 
          headwidth=7.5, 
          headlength=10, 
          headaxislength=5) 

ax.set_xlim(224000,229000)
ax.set_ylim(9025000,9030000)

ax.set_ylabel('y axis', fontweight='bold', fontsize=12)
ax.set_xlabel('x axis', fontweight='bold', fontsize=12)

ax.set_yticks(ticks=[9025500, 9027500, 9029500])
ax.set_xticks(ticks=[224500, 226500, 228500])

ax.set_yticklabels(ax.get_yticks(), rotation=90, fontsize=12, va='center')
ax.set_xticklabels(ax.get_xticks(), fontsize=12, ha='center')

ax.text(x=224500, y=9029610, s='0.01 m/s', fontsize=12)

plt.show()

# %% [markdown]
# # **8. Get the Triangle Center Location**

# %%
grid_point = pd.read_csv('/content/drive/MyDrive/Youtube Tutorial/Matplotlib Tutorial/#1 plot unstructured grid/003_VelocityVectorPlot/grid_point.csv',header=None)
grid_triangle = pd.read_csv('/content/drive/MyDrive/Youtube Tutorial/Matplotlib Tutorial/#1 plot unstructured grid/003_VelocityVectorPlot/grid_triangle.csv', header=None)

# %%
grid_triangle = grid_triangle - 1

# %%
center_x = []
center_y = []

for i in range(0, len(grid_triangle)):
  center_x.append((grid_point[0][grid_triangle[0][i]] + grid_point[0][grid_triangle[1][i]] + grid_point[0][grid_triangle[2][i]])/3)
  center_y.append((grid_point[1][grid_triangle[0][i]] + grid_point[1][grid_triangle[1][i]] + grid_point[1][grid_triangle[2][i]])/3)

center_x = np.asarray(center_x)
center_y = np.asarray(center_y)

# %% [markdown]
# # **THANK YOU**
